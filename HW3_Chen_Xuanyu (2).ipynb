# %%
#Load the data and inspect them

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c853695c-9576-4b3b-8fd9-93511e8b131a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c853695c-9576-4b3b-8fd9-93511e8b131a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TSLA.csv to TSLA.csv

# %%
import numpy as np 
import matplotlib.pyplot as plt
import torch
import pandas as pd

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['TSLA.csv']))

# %%
df2.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 1  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 2  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 3  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000
# 4  2015-07-16  52.844002  53.439999  52.632000  53.335999  53.335999   8080000

# %%
print(f"Total no. of columns : {len(df2.columns)}")
print(f"Total no. of rows  : {len(df2)}")
# Out:
# Total no. of columns : 7
# Total no. of rows  : 1259

# %%
df2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
all_data = df2['Adj Close'].values.astype(float)

# %%
print(all_data)
# Out:
# [ 51.830002  52.431999  53.130001 ... 277.971985 273.175995 278.855988]

# %%
plt.title('Days vs Adj Close')
plt.ylabel('Adj Close')
plt.xlabel('Days')
plt.grid(True)
plt.autoscale(axis='Date',tight=True)
plt.plot(df2['Adj Close'])

# %%
#Split the data into training and test sets

# %%
test_data_size = 14
train_data = df2[:-test_data_size]
test_data = df2[-test_data_size:]

# %%
print(len(train_data))
print(len(test_data))
# Out:
# 1245
# 14

# %%
training_set = df2.iloc[:600, 1:2].values
test_set = df2.iloc[600:, 1:2].values
plt.plot(training_set, label = 'Tesla Stock Price train')
plt.plot(test_set, label = 'Tesla Stock Price test')
plt.show()

# %%
#Normalized the data

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
X_train = []
y_train = []
for i in range(60, 600):
    X_train.append(training_set[i-60:i, 0])
    y_train.append(training_set[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
#Build the input features with 1 day

# %%
train_window = 1

# %%
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+tw:i+tw+1]
        inout_seq.append((train_seq ,train_label))
    return inout_seq

# %%
train_inout_seq = create_inout_sequences(X_train, train_window)

# %%
def sliding_windows(data, seq_length1):
    x = []
    y = []

    for i in range(len(data)-seq_length1-1):
        _x = data[i:(i+seq_length1)]
        _y = data[i+seq_length1]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(training_set)

seq_length1 = 1
x, y = sliding_windows(training_data, seq_length1)

train_size = int(len(y) * 0.67)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %%
#Build LSTM mode, decide how many neurons and how many layers, and design loss function and optimizer.

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length1
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
num_epochs = 2000
learning_rate = 0.01

input_size = 1
hidden_size = 4
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()
    if epoch % 100 == 0:
      print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# Epoch: 0, loss: 0.08785
# Epoch: 100, loss: 0.00631
# Epoch: 200, loss: 0.00059
# Epoch: 300, loss: 0.00059
# Epoch: 400, loss: 0.00058
# Epoch: 500, loss: 0.00058
# Epoch: 600, loss: 0.00058
# Epoch: 700, loss: 0.00058
# Epoch: 800, loss: 0.00058
# Epoch: 900, loss: 0.00058
# Epoch: 1000, loss: 0.00058
# Epoch: 1100, loss: 0.00058
# Epoch: 1200, loss: 0.00058
# Epoch: 1300, loss: 0.00058
# Epoch: 1400, loss: 0.00058
# Epoch: 1500, loss: 0.00058
# Epoch: 1600, loss: 0.00058
# Epoch: 1700, loss: 0.00058
# Epoch: 1800, loss: 0.00058
# Epoch: 1900, loss: 0.00058

# %%
fut_pred = 14

test_inputs = X_train[-train_window:].tolist()
print(test_inputs)
# Out:
# [[[67.896004], [69.933998], [70.709999], [71.223999], [70.760002], [69.900002], [69.195999], [69.797997], [70.269997], [72.898003], [72.764], [72.865997], [74.902], [76.050003], [76.0], [74.599998], [74.980003], [73.297997], [70.629997], [70.185997], [69.980003], [67.975998], [68.372002], [68.503998], [67.18], [70.25], [71.199997], [70.620003], [69.93], [69.360001], [70.778], [70.589996], [71.396004], [70.751999], [70.181999], [71.194], [71.112], [70.538002], [69.975998], [67.760002], [67.339996], [65.556], [63.950001], [63.835999], [64.045998], [66.449997], [60.026001], [59.900002], [61.400002], [60.203999], [61.099998], [60.5], [60.5], [60.026001], [63.0], [61.202], [62.798], [65.134003], [62.757999], [62.172001]]]

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()

# %%
num_epochs = 10000
learning_rate = 0.01

input_size = 1
hidden_size = 4
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()
    if epoch % 100 == 0:
      print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# Epoch: 0, loss: 0.08609
# Epoch: 100, loss: 0.00659
# Epoch: 200, loss: 0.00078
# Epoch: 300, loss: 0.00058
# Epoch: 400, loss: 0.00057
# Epoch: 500, loss: 0.00057
# Epoch: 600, loss: 0.00057
# Epoch: 700, loss: 0.00057
# Epoch: 800, loss: 0.00057
# Epoch: 900, loss: 0.00057
# Epoch: 1000, loss: 0.00057
# Epoch: 1100, loss: 0.00057
# Epoch: 1200, loss: 0.00057
# Epoch: 1300, loss: 0.00057
# Epoch: 1400, loss: 0.00057
# Epoch: 1500, loss: 0.00057
# Epoch: 1600, loss: 0.00057
# Epoch: 1700, loss: 0.00057
# Epoch: 1800, loss: 0.00057
# Epoch: 1900, loss: 0.00057
# Epoch: 2000, loss: 0.00057
# Epoch: 2100, loss: 0.00057
# Epoch: 2200, loss: 0.00057
# Epoch: 2300, loss: 0.00057
# Epoch: 2400, loss: 0.00057
# Epoch: 2500, loss: 0.00057
# Epoch: 2600, loss: 0.00057
# Epoch: 2700, loss: 0.00057
# Epoch: 2800, loss: 0.00057
# Epoch: 2900, loss: 0.00057
# Epoch: 3000, loss: 0.00057
# Epoch: 3100, loss: 0.00057
# Epoch: 3200, loss: 0.00057
# Epoch: 3300, loss: 0.00057
# Epoch: 3400, loss: 0.00057
# Epoch: 3500, loss: 0.00057
# Epoch: 3600, loss: 0.00057
# Epoch: 3700, loss: 0.00057
# Epoch: 3800, loss: 0.00057
# Epoch: 3900, loss: 0.00057
# Epoch: 4000, loss: 0.00057
# Epoch: 4100, loss: 0.00057
# Epoch: 4200, loss: 0.00057
# Epoch: 4300, loss: 0.00057
# Epoch: 4400, loss: 0.00057
# Epoch: 4500, loss: 0.00057
# Epoch: 4600, loss: 0.00057
# Epoch: 4700, loss: 0.00057
# Epoch: 4800, loss: 0.00057
# Epoch: 4900, loss: 0.00057
# Epoch: 5000, loss: 0.00057
# Epoch: 5100, loss: 0.00060
# Epoch: 5200, loss: 0.00057
# Epoch: 5300, loss: 0.00057
# Epoch: 5400, loss: 0.00057
# Epoch: 5500, loss: 0.00057
# Epoch: 5600, loss: 0.00057
# Epoch: 5700, loss: 0.00057
# Epoch: 5800, loss: 0.00057
# Epoch: 5900, loss: 0.00057
# Epoch: 6000, loss: 0.00057
# Epoch: 6100, loss: 0.00057
# Epoch: 6200, loss: 0.00060
# Epoch: 6300, loss: 0.00057
# Epoch: 6400, loss: 0.00057
# Epoch: 6500, loss: 0.00057
# Epoch: 6600, loss: 0.00057
# Epoch: 6700, loss: 0.00057
# Epoch: 6800, loss: 0.00057
# Epoch: 6900, loss: 0.00057
# Epoch: 7000, loss: 0.00057
# Epoch: 7100, loss: 0.00057
# Epoch: 7200, loss: 0.00057
# Epoch: 7300, loss: 0.00057
# Epoch: 7400, loss: 0.00057
# Epoch: 7500, loss: 0.00057
# Epoch: 7600, loss: 0.00058
# Epoch: 7700, loss: 0.00057
# Epoch: 7800, loss: 0.00057
# Epoch: 7900, loss: 0.00058
# Epoch: 8000, loss: 0.00057
# Epoch: 8100, loss: 0.00057
# Epoch: 8200, loss: 0.00058
# Epoch: 8300, loss: 0.00057
# Epoch: 8400, loss: 0.00057
# Epoch: 8500, loss: 0.00058
# Epoch: 8600, loss: 0.00057
# Epoch: 8700, loss: 0.00057
# Epoch: 8800, loss: 0.00057
# Epoch: 8900, loss: 0.00057
# Epoch: 9000, loss: 0.00057
# Epoch: 9100, loss: 0.00057
# Epoch: 9200, loss: 0.00057
# Epoch: 9300, loss: 0.00057
# Epoch: 9400, loss: 0.00057
# Epoch: 9500, loss: 0.00057
# Epoch: 9600, loss: 0.00057
# Epoch: 9700, loss: 0.00057
# Epoch: 9800, loss: 0.00057
# Epoch: 9900, loss: 0.00060

# %%
fut_pred = 14

test_inputs = X_train[-train_window:].tolist()
print(test_inputs)
# Out:
# [[[67.896004], [69.933998], [70.709999], [71.223999], [70.760002], [69.900002], [69.195999], [69.797997], [70.269997], [72.898003], [72.764], [72.865997], [74.902], [76.050003], [76.0], [74.599998], [74.980003], [73.297997], [70.629997], [70.185997], [69.980003], [67.975998], [68.372002], [68.503998], [67.18], [70.25], [71.199997], [70.620003], [69.93], [69.360001], [70.778], [70.589996], [71.396004], [70.751999], [70.181999], [71.194], [71.112], [70.538002], [69.975998], [67.760002], [67.339996], [65.556], [63.950001], [63.835999], [64.045998], [66.449997], [60.026001], [59.900002], [61.400002], [60.203999], [61.099998], [60.5], [60.5], [60.026001], [63.0], [61.202], [62.798], [65.134003], [62.757999], [62.172001]]]

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()
